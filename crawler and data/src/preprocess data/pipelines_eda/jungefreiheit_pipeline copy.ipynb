# %% [markdown]
# ## Data Analysis pipeline for all datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel(r"C:\github\news\news\german-news\clean_data\xlsx\jungefreiheit.xlsx")
df
# Out:
#         news_outlet                                         provenance  \
# 0     jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
# 1     jungefreiheit  https://jungefreiheit.de/debatte/kommentar/202...
# 2     jungefreiheit  https://jungefreiheit.de/wirtschaft/2024/erbsc...
# 3     jungefreiheit  https://jungefreiheit.de/kultur/2023/neo-rauch...
# 4     jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
# ...             ...                                                ...
# 1000  jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
# 1001  jungefreiheit  https://jungefreiheit.de/wirtschaft/2022/kfz-n...
# 1002  jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
# 1003  jungefreiheit  https://jungefreiheit.de/wirtschaft/2023/habec...
# 1004  jungefreiheit  https://jungefreiheit.de/kultur/medien/2024/ju...
#
#                                          query_keywords  creation_date  \
# 0     usa, spd, demo, ns, rna, us, ss, bundestagswah...            NaN
# 1                          schi, christ, ns, us, ss, sp            NaN
# 2     usa, sp, spd, schi, politik, bruttoinlandsprod...            NaN
# 3               regierung, schi, kultur, ns, us, ss, sp            NaN
# 4         muslim, asyl, schi, demo, ns, us, ss, afd, sp            NaN
# ...                                                 ...            ...
# 1000               regierung, schi, ns, us, ss, spo, sp            NaN
# 1001  ukraine, frankreich, krieg, lockdown, corona, ...            NaN
# 1002                   muslim, spd, ns, rna, us, ss, sp            NaN
# 1003         xi, ns, us, ss, familie, sp, robert habeck            NaN
# 1004                                 xi, ns, us, ss, sp            NaN
#
#      last_modified crawl_date  author_person  author_organization  \
# 0              NaT 2024-11-21            NaN                  NaN
# 1              NaT 2024-11-21            NaN                  NaN
# 2              NaT 2024-11-21            NaN                  NaN
# 3              NaT 2024-11-21            NaN                  NaN
# 4              NaT 2024-11-21            NaN                  NaN
# ...            ...        ...            ...                  ...
# 1000           NaT 2024-11-21            NaN                  NaN
# 1001           NaT 2024-11-21            NaN                  NaN
# 1002           NaT 2024-11-21            NaN                  NaN
# 1003           NaT 2024-11-21            NaN                  NaN
# 1004           NaT 2024-11-21            NaN                  NaN
#
#                                           news_keywords  \
# 0     K-Frage, Lars Klingbeil, Pistorius Kanzlerkand...
# 1      Berlin, Diskothek, Gender, Geschlechtsidentitaet
# 2           Erbschaftssteuer, Sozialpolitik, Wirtschaft
# 3     Bundesregierung, Deutschland schafft sich ab, ...
# 4     AfD, Bundesamt fuer Verfassungsschutz, Junge A...
# ...                                                 ...
# 1000  9-Euro-Ticket, Bahn, Deutsche Polizeigewerksch...
# 1001  Automobilhersteller, Automobilindustrie, Neuzu...
# 1002  Antisemitismus, Freie Universitaet Berlin, Pro...
# 1003  Foerderungen, Gebaeudeenergiegesetz, Gruene, H...
# 1004  Berlin, Junge Welt, Klage, Verfassungsschutz, ...
#
#                                           content_title  \
# 0     Haengepartie Scholz gegen Pistorius: Wann ist ...
# 1                       Zwei Seelen und 53 Geschlechter
# 2     Erbschaftssteuer  Alle dreissig Jahre ein Ader...
# 3                Maler Neo Rauch: Ich liebe dieses Land
# 4     Verfassungsschutz darf AfD-Jugend als gesicher...
# ...                                                 ...
# 1000  Neun-Euro-Ticket: Polizeigewerkschaft warnt vo...
# 1001     Neuzulassungen von Kraftfahrzeugen brechen ein
# 1002  Berliner Universitaet darf antisemitischen Sch...
# 1003  Habeck streicht Zuschuesse fuer Waermepumpen r...
# 1004        Junge Welt verliert gegen Verfassungsschutz
#
#                                     content_description  \
# 0     Die SPD bekommt die Debatte um ihren Kanzlerka...
# 1     Im Berliner Nachtleben geht es nicht nur ums p...
# 2     Die deutsche Erbschaftsteuer ist im internatio...
# 3     Der weltbekannte Kuenstler uebt scharfe Kritik...
# 4     Die Junge Alternative wird vom Verfassungsschu...
# ...                                                 ...
# 1000  Das Neun-Euro-Ticket fuer den oeffentlichen Na...
# 1001  Die Neuzulassung von Kraftfahrzeugen ist in de...
# 1002  Nach der Pruegelattacke auf einen juedischen S...
# 1003  Der Gruene bricht sein Versprechen, die Umrues...
# 1004  Wir streben keine Gesellschaftsordnung an, son...
#
#                                            content_body  Fake News  \
# 0     Bei den Sozialdemokraten ist eine Debatte daru...        NaN
# 1     Wir befinden uns im Jahr 2024 nach Christus. G...        1.0
# 2     Eine aktuelle Studie zeigt: Nirgendwo in Europ...        NaN
# 3     LEIPZIG. Mit einem Bekenntnis zum Patriotismus...        NaN
# 4     Die Koelner Richter bestaetigten mit ihrem nun...        0.0
# ...                                                 ...        ...
# 1000  BERLIN. Der Bundesvorsitzende der Deutschen Po...        NaN
# 1001  BRUESSEL. Die Neuzulassung von Kraftfahrzeugen...        NaN
# 1002  BERLIN. Berlins Wissenschaftssenatorin Ina Czy...        NaN
# 1003  BERLIN. Um bis zu 9.000 Euro niedriger als der...        NaN
# 1004  BERLIN. Das Verwaltungsgericht Berlin hat eine...        0.0
#
#       Extreme bias  clickbait  credible
# 0              NaN        NaN       NaN
# 1              1.0        1.0       0.0
# 2              NaN        NaN       NaN
# 3              NaN        NaN       NaN
# 4              1.0        0.0       1.0
# ...            ...        ...       ...
# 1000           NaN        NaN       NaN
# 1001           NaN        NaN       NaN
# 1002           NaN        NaN       NaN
# 1003           NaN        NaN       NaN
# 1004           0.0        0.0       1.0
#
# [1005 rows x 16 columns]

# %% [markdown]
# We will first have to get a look at our data and understand it

# %%
labels = ['Fake News', 'Extreme bias', 'clickbait', 'credible']
df[labels].sum()
# Out:
# Fake News       54.0
# Extreme bias    57.0
# clickbait       37.0
# credible        20.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   news_outlet          1005 non-null   object
#  1   provenance           1005 non-null   object
#  2   query_keywords       1005 non-null   object
#  3   creation_date        0 non-null      float64
#  4   last_modified        17 non-null     datetime64[ns]
#  5   crawl_date           1005 non-null   datetime64[ns]
#  6   author_person        0 non-null      float64
#  7   author_organization  0 non-null      float64
#  8   news_keywords        1001 non-null   object
#  9   content_title        1005 non-null   object
#  10  content_description  1005 non-null   object
#  11  content_body         1002 non-null   object
#  12  Fake News            79 non-null     float64
#  13  Extreme bias         79 non-null     float64
#  14  clickbait            79 non-null     float64
#  15  credible             79 non-null     float64
# dtypes: datetime64[ns](2), float64(7), object(7)
# memory usage: 125.8+ KB

# %% [markdown]
# plot of label distr

# %%
def plot_label_distribution(df, labels):
    label_counts = df[labels].sum()
    label_counts.plot(kind='bar', figsize=(8, 5), color=['red', 'orange', 'yellow', 'green'])
    plt.title('Label Distribution')
    plt.xlabel('Labels')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

labels = ['Fake News', 'Extreme bias', 'clickbait', 'credible']
plot_label_distribution(df, labels)

# %% [markdown]
# text length distribution

# %%
df['body_len'] = df['content_body'].str.len()

def plot_text_length_distribution(df, column):
    plt.hist(df[column], bins=50, color='blue', alpha=0.7)
    plt.title(f'{column} Length Distribution')
    plt.xlabel('Text Length')
    plt.ylabel('Frequency')
    plt.show()

plot_text_length_distribution(df, 'body_len')

# %% [markdown]
# len of article vs label

# %%
def plot_length_vs_label(df, labels, length_column):
    plt.figure(figsize=(12, 8))
    for label in labels:
        filtered = df[df[label] == 1]
        plt.hist(
            filtered[length_column], 
            bins=50, 
            alpha=0.5, 
            label=label,
            range=(0, df[length_column].max())
        )
    plt.title(f'Article Length vs Labels')
    plt.xlabel('Article Length')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

plot_length_vs_label(df, labels, 'body_len')

# %% [markdown]
# visualize titles

# %%
def create_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=20)
    plt.axis('off')
    plt.show()

create_wordcloud(df['content_body'].dropna(), 'Content Title WordCloud')

# %% [markdown]
# visualize text

# %%
def create_wordcloud(text, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(text))
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=20)
    plt.axis('off')
    plt.show()

create_wordcloud(df['content_title'].dropna(), 'Content Body WordCloud')

# %% [markdown]
# split df to labelled and not labelled

# %%
df['has_label'] = df[labels].notna().any(axis=1)
labelled_df = df[df['has_label']]
unlabelled_df = df[~df['has_label']]

print(f"Labelled Data: {len(labelled_df)} rows")
print(f"Unlabelled Data: {len(unlabelled_df)} rows")
# Out:
# Labelled Data: 79 rows
# Unlabelled Data: 926 rows

# %%
labelled_df.head()
# Out:
#       news_outlet                                         provenance  \
# 1   jungefreiheit  https://jungefreiheit.de/debatte/kommentar/202...
# 4   jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
# 5   jungefreiheit  https://jungefreiheit.de/debatte/kommentar/202...
# 6   jungefreiheit  https://jungefreiheit.de/wirtschaft/2024/neue-...
# 17  jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
#
#                                        query_keywords  creation_date  \
# 1                        schi, christ, ns, us, ss, sp            NaN
# 4       muslim, asyl, schi, demo, ns, us, ss, afd, sp            NaN
# 5   israel, christ, klima, pandemie, kultur, cdu, ...            NaN
# 6                 politik, klima, ns, cdu, us, ss, sp            NaN
# 17  regierung, asyl, schi, politik, migration, ns,...            NaN
#
#    last_modified crawl_date  author_person  author_organization  \
# 1            NaT 2024-11-21            NaN                  NaN
# 4            NaT 2024-11-21            NaN                  NaN
# 5            NaT 2024-11-21            NaN                  NaN
# 6            NaT 2024-11-21            NaN                  NaN
# 17           NaT 2024-11-21            NaN                  NaN
#
#                                         news_keywords  \
# 1    Berlin, Diskothek, Gender, Geschlechtsidentitaet
# 4   AfD, Bundesamt fuer Verfassungsschutz, Junge A...
# 5   Christentum, EKD, Evangelische Kirche, Jesus C...
# 6   Batterien, Elektromobilitaet, EU, Ladesaeulen,...
# 17                    Gewalt, Kriminalitaet, Tunesier
#
#                                         content_title  \
# 1                     Zwei Seelen und 53 Geschlechter
# 4   Verfassungsschutz darf AfD-Jugend als gesicher...
# 5   Weihnachten in Zeiten der Kirchenkrise: Kein P...
# 6        Neue Zweifel an von der Leyens E-Auto-Diktat
# 17  80 Prozent der jungen Tunesier waren Tatverdae...
#
#                                   content_description  \
# 1   Im Berliner Nachtleben geht es nicht nur ums p...
# 4   Die Junge Alternative wird vom Verfassungsschu...
# 5   Die Zeit vor Weihnachten sorgt fuer erneute De...
# 6   Der Europaeische Rechnungshof kritisiert das v...
# 17  Die Bundesregierung behauptet, Herkunft und Kr...
#
#                                          content_body  Fake News  \
# 1   Wir befinden uns im Jahr 2024 nach Christus. G...        1.0
# 4   Die Koelner Richter bestaetigten mit ihrem nun...        0.0
# 5   Koennen, ja duerfen wir noch Weihnachten feier...        1.0
# 6   LUXEMBURG. Der Europaeische Rechnungshof hat Z...        0.0
# 17  SCHWERIN. Die Kriminalitaetsbelastung junger T...        1.0
#
#     Extreme bias  clickbait  credible  body_len  has_label
# 1            1.0        1.0       0.0     805.0       True
# 4            1.0        0.0       1.0    1684.0       True
# 5            1.0        1.0       0.0    6512.0       True
# 6            0.0        0.0       1.0    1808.0       True
# 17           1.0        1.0       0.0    1346.0       True

# %% [markdown]
# encode labels

# %%
def encode_labels(row, labels):
    return [int(row[label]) for label in labels]

labelled_df['label'] = labelled_df.apply(lambda row: encode_labels(row, labels), axis=1)

labelled_df = labelled_df.rename(
    columns={
        'content_title': 'title',
        'content_description': 'description',
        'content_body': 'body'
    }
)
# Out:
# C:\Users\hanna\AppData\Local\Temp\ipykernel_14464\55246372.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labelled_df['label'] = labelled_df.apply(lambda row: encode_labels(row, labels), axis=1)

# %%
labelled_df.head()
# Out:
#       news_outlet                                         provenance  \
# 1   jungefreiheit  https://jungefreiheit.de/debatte/kommentar/202...
# 4   jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
# 5   jungefreiheit  https://jungefreiheit.de/debatte/kommentar/202...
# 6   jungefreiheit  https://jungefreiheit.de/wirtschaft/2024/neue-...
# 17  jungefreiheit  https://jungefreiheit.de/politik/deutschland/2...
#
#                                        query_keywords  creation_date  \
# 1                        schi, christ, ns, us, ss, sp            NaN
# 4       muslim, asyl, schi, demo, ns, us, ss, afd, sp            NaN
# 5   israel, christ, klima, pandemie, kultur, cdu, ...            NaN
# 6                 politik, klima, ns, cdu, us, ss, sp            NaN
# 17  regierung, asyl, schi, politik, migration, ns,...            NaN
#
#    last_modified crawl_date  author_person  author_organization  \
# 1            NaT 2024-11-21            NaN                  NaN
# 4            NaT 2024-11-21            NaN                  NaN
# 5            NaT 2024-11-21            NaN                  NaN
# 6            NaT 2024-11-21            NaN                  NaN
# 17           NaT 2024-11-21            NaN                  NaN
#
#                                         news_keywords  \
# 1    Berlin, Diskothek, Gender, Geschlechtsidentitaet
# 4   AfD, Bundesamt fuer Verfassungsschutz, Junge A...
# 5   Christentum, EKD, Evangelische Kirche, Jesus C...
# 6   Batterien, Elektromobilitaet, EU, Ladesaeulen,...
# 17                    Gewalt, Kriminalitaet, Tunesier
#
#                                                 title  \
# 1                     Zwei Seelen und 53 Geschlechter
# 4   Verfassungsschutz darf AfD-Jugend als gesicher...
# 5   Weihnachten in Zeiten der Kirchenkrise: Kein P...
# 6        Neue Zweifel an von der Leyens E-Auto-Diktat
# 17  80 Prozent der jungen Tunesier waren Tatverdae...
#
#                                           description  \
# 1   Im Berliner Nachtleben geht es nicht nur ums p...
# 4   Die Junge Alternative wird vom Verfassungsschu...
# 5   Die Zeit vor Weihnachten sorgt fuer erneute De...
# 6   Der Europaeische Rechnungshof kritisiert das v...
# 17  Die Bundesregierung behauptet, Herkunft und Kr...
#
#                                                  body  Fake News  \
# 1   Wir befinden uns im Jahr 2024 nach Christus. G...        1.0
# 4   Die Koelner Richter bestaetigten mit ihrem nun...        0.0
# 5   Koennen, ja duerfen wir noch Weihnachten feier...        1.0
# 6   LUXEMBURG. Der Europaeische Rechnungshof hat Z...        0.0
# 17  SCHWERIN. Die Kriminalitaetsbelastung junger T...        1.0
#
#     Extreme bias  clickbait  credible  body_len  has_label         label
# 1            1.0        1.0       0.0     805.0       True  [1, 1, 1, 0]
# 4            1.0        0.0       1.0    1684.0       True  [0, 1, 0, 1]
# 5            1.0        1.0       0.0    6512.0       True  [1, 1, 1, 0]
# 6            0.0        0.0       1.0    1808.0       True  [0, 0, 0, 1]
# 17           1.0        1.0       0.0    1346.0       True  [1, 1, 1, 0]

# %% [markdown]
# we can drop, whatever we dont need, later

# %% [markdown]
# export data

# %%
labelled_df.to_csv(r'C:\github\news\news\german-news\preprocess data\data_ready_for_analysis\labelled\jf_labelled_data.csv', index=False)
unlabelled_df.to_csv(r'C:\github\news\news\german-news\preprocess data\data_ready_for_analysis\unlabelled\jf_unlabelled_data.csv', index=False)
